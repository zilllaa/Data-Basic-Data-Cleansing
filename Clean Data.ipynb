# %% [markdown]
# # CLEANSING DATA AMAZON PRIME TITLES

# %% [markdown]
# Nama :
#
#     1. Maulita Nur Sejati
#
#     2. Ryan Artista Rahman
#
#     3. Prita Ayu Meudea
#
#     4. Tanzilla Oktavia Widodo
#
#     5. Diva Keishya Kirana

# %% [markdown]
# ### Python Libraries Import

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %% [markdown]
# ### Load data set

# %% [markdown]
# Create a data frame then load the data set. Here the dataset used is amazon_prime_titles.

# %%
df=pd.read_csv('amazon_prime_titles.csv')

# %% [markdown]
# Displays the data set that has been loaded

# %%
df.head()
# Out:
#   show_id   type                 title        director  \
# 0      s1  Movie   The Grand Seduction    Don McKellar
# 1      s2  Movie  Take Care Good Night    Girish Joshi
# 2      s3  Movie  Secrets of Deception     Josh Webber
# 3      s4  Movie    Pink: Staying True  Sonia Anderson
# 4      s5  Movie         Monster Maker    Giles Foster
#
#                                                 cast         country  \
# 0     Brendan Gleeson, Taylor Kitsch, Gordon Pinsent          Canada
# 1   Mahesh Manjrekar, Abhay Mahajan, Sachin Khedekar           India
# 2  Tom Sizemore, Lorenzo Lamas, Robert LaSardo, R...   United States
# 3  Interviews with: Pink, Adele, Beyoncé, Britney...   United States
# 4  Harry Dean Stanton, Kieran O'Brien, George Cos...  United Kingdom
#
#        date_added  release_year rating duration                listed_in  \
# 0  March 30, 2021          2014    NaN  113 min            Comedy, Drama
# 1  March 30, 2021          2018    13+  110 min     Drama, International
# 2  March 30, 2021          2017    NaN   74 min  Action, Drama, Suspense
# 3  March 30, 2021          2014    NaN   69 min              Documentary
# 4  March 30, 2021          1989    NaN   45 min           Drama, Fantasy
#
#                                          description
# 0  A small fishing village must procure a local d...
# 1  A Metro Family decides to fight a Cyber Crimin...
# 2  After a man discovers his wife is cheating on ...
# 3  Pink breaks the mold once again, bringing her ...
# 4  Teenage Matt Banting wants to work with a famo...

# %% [markdown]
# ### Check data condition

# %%
df.shape
# Out:
# (9668, 12)

# %% [markdown]
# 9668 : rows, 12 : columns

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9668 entries, 0 to 9667
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       9668 non-null   object
#  1   type          9668 non-null   object
#  2   title         9668 non-null   object
#  3   director      7585 non-null   object
#  4   cast          8435 non-null   object
#  5   country       672 non-null    object
#  6   date_added    155 non-null    object
#  7   release_year  9668 non-null   int64
#  8   rating        9331 non-null   object
#  9   duration      9668 non-null   object
#  10  listed_in     9668 non-null   object
#  11  description   9668 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 906.5+ KB

# %% [markdown]
# #### Check Percentage Missing Values

# %%
missing_values = df.isnull().sum()

missing_percentages = (missing_values / len(df)) * 100

missing_info = pd.DataFrame({
    'Column': missing_values.index,
    'Missing Values': missing_values.values,
    'Missing Percentage': missing_percentages.values
})

print(missing_info)
# Out:
#           Column  Missing Values  Missing Percentage
# 0        show_id               0            0.000000
# 1           type               0            0.000000
# 2          title               0            0.000000
# 3       director            2083           21.545304
# 4           cast            1233           12.753413
# 5        country            8996           93.049235
# 6     date_added            9513           98.396773
# 7   release_year               0            0.000000
# 8         rating             337            3.485726
# 9       duration               0            0.000000
# 10     listed_in               0            0.000000
# 11   description               0            0.000000

# %% [markdown]
# #### Insights and Considerations

# %% [markdown]
# Data Completeness:
# Columns like 'director,' 'cast,' 'country,' 'date_added,' 'rating,' and others have missing values that need attention.
#
# Data Types:
# The 'release_year' column is correctly identified as an integer ('int64'). Other columns, such as 'date_added' and 'duration,' might need conversion to datetime or numeric types if they contain date or duration information.

# %% [markdown]
# ### Check and remove duplicate rows from the DataFrame

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Count duplicate is 0

# %% [markdown]
# ### Drop the columns 'date_added' and 'country', from the DataFrame
#
# Because country and date_added column have so many missing data (more than 50%) and there are barely use of them, we will drop them

# %%
df.drop(['date_added','country'], axis = 1, inplace=True)
df.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'release_year',
#        'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %% [markdown]
# Show dataset info to see if the date and country columns are missing.
# #### Check the others columns missing values.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9668 entries, 0 to 9667
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       9668 non-null   object
#  1   type          9668 non-null   object
#  2   title         9668 non-null   object
#  3   director      7585 non-null   object
#  4   cast          8435 non-null   object
#  5   release_year  9668 non-null   int64
#  6   rating        9331 non-null   object
#  7   duration      9668 non-null   object
#  8   listed_in     9668 non-null   object
#  9   description   9668 non-null   object
# dtypes: int64(1), object(9)
# memory usage: 755.4+ KB

# %% [markdown]
# ### Enhance data
# #### rename kolom listed in

# %%
df.rename(columns={'listed_in' : 'categories'},inplace=True)
df.head(2)
# Out:
#   show_id   type                 title      director  \
# 0      s1  Movie   The Grand Seduction  Don McKellar
# 1      s2  Movie  Take Care Good Night  Girish Joshi
#
#                                                cast  release_year rating  \
# 0    Brendan Gleeson, Taylor Kitsch, Gordon Pinsent          2014    NaN
# 1  Mahesh Manjrekar, Abhay Mahajan, Sachin Khedekar          2018    13+
#
#   duration            categories  \
# 0  113 min         Comedy, Drama
# 1  110 min  Drama, International
#
#                                          description
# 0  A small fishing village must procure a local d...
# 1  A Metro Family decides to fight a Cyber Crimin...

# %% [markdown]
# #### To solve the data type problems at duration and date added.
# - Date added has deleted.
# - Then we get attention at the duration columns.
#
# Create a new column named 'duration_num' in the DataFrame,
# to return the numerical.

# %%
df['duration_num'] = df['duration'].str.extract('(\d+)').astype(float)

# %% [markdown]
# We will split the duration column into duration_movie and duration_season

# %%
df['duration_movie'] = df['duration'].str.extract('(\d+) min', expand=False)

df['duration_season'] = df['duration'].str.extract('(\d+) Seasons', expand=False)

df.drop('duration', axis=1, inplace=True)

df.head()
# Out:
#   show_id   type                 title        director  \
# 0      s1  Movie   The Grand Seduction    Don McKellar
# 1      s2  Movie  Take Care Good Night    Girish Joshi
# 2      s3  Movie  Secrets of Deception     Josh Webber
# 3      s4  Movie    Pink: Staying True  Sonia Anderson
# 4      s5  Movie         Monster Maker    Giles Foster
#
#                                                 cast  release_year rating  \
# 0     Brendan Gleeson, Taylor Kitsch, Gordon Pinsent          2014    NaN
# 1   Mahesh Manjrekar, Abhay Mahajan, Sachin Khedekar          2018    13+
# 2  Tom Sizemore, Lorenzo Lamas, Robert LaSardo, R...          2017    NaN
# 3  Interviews with: Pink, Adele, Beyoncé, Britney...          2014    NaN
# 4  Harry Dean Stanton, Kieran O'Brien, George Cos...          1989    NaN
#
#                 categories                                        description  \
# 0            Comedy, Drama  A small fishing village must procure a local d...
# 1     Drama, International  A Metro Family decides to fight a Cyber Crimin...
# 2  Action, Drama, Suspense  After a man discovers his wife is cheating on ...
# 3              Documentary  Pink breaks the mold once again, bringing her ...
# 4           Drama, Fantasy  Teenage Matt Banting wants to work with a famo...
#
#    duration_num duration_movie duration_season
# 0         113.0            113             NaN
# 1         110.0            110             NaN
# 2          74.0             74             NaN
# 3          69.0             69             NaN
# 4          45.0             45             NaN

# %% [markdown]
# We will divide the genre into muliple column

# %%
df[['Genre1', 'Genre2', 'Genre3']] = df['categories'].str.split(',', expand=True, n=2)

# %%
df.head()
# Out:
#   show_id   type                 title        director  \
# 0      s1  Movie   The Grand Seduction    Don McKellar
# 1      s2  Movie  Take Care Good Night    Girish Joshi
# 2      s3  Movie  Secrets of Deception     Josh Webber
# 3      s4  Movie    Pink: Staying True  Sonia Anderson
# 4      s5  Movie         Monster Maker    Giles Foster
#
#                                                 cast  release_year rating  \
# 0     Brendan Gleeson, Taylor Kitsch, Gordon Pinsent          2014    NaN
# 1   Mahesh Manjrekar, Abhay Mahajan, Sachin Khedekar          2018    13+
# 2  Tom Sizemore, Lorenzo Lamas, Robert LaSardo, R...          2017    NaN
# 3  Interviews with: Pink, Adele, Beyoncé, Britney...          2014    NaN
# 4  Harry Dean Stanton, Kieran O'Brien, George Cos...          1989    NaN
#
#                 categories                                        description  \
# 0            Comedy, Drama  A small fishing village must procure a local d...
# 1     Drama, International  A Metro Family decides to fight a Cyber Crimin...
# 2  Action, Drama, Suspense  After a man discovers his wife is cheating on ...
# 3              Documentary  Pink breaks the mold once again, bringing her ...
# 4           Drama, Fantasy  Teenage Matt Banting wants to work with a famo...
#
#    duration_num duration_movie duration_season       Genre1          Genre2  \
# 0         113.0            113             NaN       Comedy           Drama
# 1         110.0            110             NaN        Drama   International
# 2          74.0             74             NaN       Action           Drama
# 3          69.0             69             NaN  Documentary            None
# 4          45.0             45             NaN        Drama         Fantasy
#
#       Genre3
# 0       None
# 1       None
# 2   Suspense
# 3       None
# 4       None

# %% [markdown]
# ### Handling Missing Values
# Check the others missing values.

# %%
df.isnull().sum()
# Out:
# show_id               0
# type                  0
# title                 0
# director           2083
# cast               1233
# release_year          0
# rating              337
# categories            0
# description           0
# duration_num          0
# duration_movie     1854
# duration_season    9156
# Genre1                0
# Genre2             3839
# Genre3             7612
# dtype: int64

# %% [markdown]
# Then we can fill the missing values with 'unavailable' for columns who are not the categorical and numerical columns.
#
# Fill the rating columns with the mode method.

# %%
df['director'].fillna('Unavailable', inplace=True)
df['cast'].fillna('Unavailable', inplace=True)
df['duration_season'].fillna('Unavailable', inplace=True)
df['duration_movie'].fillna('Unavailable', inplace=True)
df['Genre1'].fillna('Unavailable', inplace=True)
df['Genre2'].fillna('Unavailable', inplace=True)
df['Genre3'].fillna('Unavailable', inplace=True)

df['rating'] = df['rating'].fillna(df['rating'].mode()[0])

# %%
df
# Out:
#      show_id     type                    title         director  \
# 0         s1    Movie      The Grand Seduction     Don McKellar
# 1         s2    Movie     Take Care Good Night     Girish Joshi
# 2         s3    Movie     Secrets of Deception      Josh Webber
# 3         s4    Movie       Pink: Staying True   Sonia Anderson
# 4         s5    Movie            Monster Maker     Giles Foster
# ...      ...      ...                      ...              ...
# 9663   s9664    Movie      Pride Of The Bowery  Joseph H. Lewis
# 9664   s9665  TV Show            Planet Patrol      Unavailable
# 9665   s9666    Movie                  Outpost     Steve Barker
# 9666   s9667  TV Show  Maradona: Blessed Dream      Unavailable
# 9667   s9668    Movie              Harry Brown    Daniel Barber
#
#                                                    cast  release_year rating  \
# 0        Brendan Gleeson, Taylor Kitsch, Gordon Pinsent          2014    13+
# 1      Mahesh Manjrekar, Abhay Mahajan, Sachin Khedekar          2018    13+
# 2     Tom Sizemore, Lorenzo Lamas, Robert LaSardo, R...          2017    13+
# 3     Interviews with: Pink, Adele, Beyoncé, Britney...          2014    13+
# 4     Harry Dean Stanton, Kieran O'Brien, George Cos...          1989    13+
# ...                                                 ...           ...    ...
# 9663                           Leo Gorcey, Bobby Jordan          1940     7+
# 9664  DICK VOSBURGH, RONNIE STEVENS, LIBBY MORRIS, M...          2018    13+
# 9665  Ray Stevenson, Julian Wadham, Richard Brake, M...          2008      R
# 9666  Esteban Recagno, Ezequiel Stremiz, Luciano Vit...          2021  TV-MA
# 9667  Michael Caine, Emily Mortimer, Joseph Gilgun, ...          2010      R
#
#                    categories  \
# 0               Comedy, Drama
# 1        Drama, International
# 2     Action, Drama, Suspense
# 3                 Documentary
# 4              Drama, Fantasy
# ...                       ...
# 9663                   Comedy
# 9664                 TV Shows
# 9665                   Action
# 9666            Drama, Sports
# 9667  Action, Drama, Suspense
#
#                                             description  duration_num  \
# 0     A small fishing village must procure a local d...         113.0
# 1     A Metro Family decides to fight a Cyber Crimin...         110.0
# 2     After a man discovers his wife is cheating on ...          74.0
# 3     Pink breaks the mold once again, bringing her ...          69.0
# 4     Teenage Matt Banting wants to work with a famo...          45.0
# ...                                                 ...           ...
# 9663  New York City street principles get an East Si...          60.0
# 9664  This is Earth, 2100AD - and these are the adve...           4.0
# 9665  In war-torn Eastern Europe, a world-weary grou...          90.0
# 9666  The series tells the story of Diego Maradona, ...           1.0
# 9667  Harry Brown, starring two-time Academy Award w...         103.0
#
#      duration_movie duration_season       Genre1          Genre2       Genre3
# 0               113     Unavailable       Comedy           Drama  Unavailable
# 1               110     Unavailable        Drama   International  Unavailable
# 2                74     Unavailable       Action           Drama     Suspense
# 3                69     Unavailable  Documentary     Unavailable  Unavailable
# 4                45     Unavailable        Drama         Fantasy  Unavailable
# ...             ...             ...          ...             ...          ...
# 9663             60     Unavailable       Comedy     Unavailable  Unavailable
# 9664    Unavailable               4     TV Shows     Unavailable  Unavailable
# 9665             90     Unavailable       Action     Unavailable  Unavailable
# 9666    Unavailable     Unavailable        Drama          Sports  Unavailable
# 9667            103     Unavailable       Action           Drama     Suspense
#
# [9668 rows x 15 columns]

# %% [markdown]
# #### Check the missing values

# %%
df.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director           0
# cast               0
# release_year       0
# rating             0
# categories         0
# description        0
# duration_num       0
# duration_movie     0
# duration_season    0
# Genre1             0
# Genre2             0
# Genre3             0
# dtype: int64

# %% [markdown]
# ### Check Outliers
# Analyze the distribution of film duration for 'Movie' type films.
#
# The calculated lower and upper bounds can then be used to identify and manage outliers in the film's duration.

# %%
movie_df = df[df['type'] == 'Movie']

q1_movie = movie_df['duration_num'].quantile(0.25)
q3_movie = movie_df['duration_num'].quantile(0.75)

print("Quartil 1 (Q1) untuk Movie:", q1_movie)
print("Quartil 3 (Q3) untuk Movie:", q3_movie)

iqr=q3_movie-q1_movie
print('IQR : ',iqr)

lwr_bound = q1_movie - (1.5 * iqr) #lower bound
upr_bound = q3_movie + (1.5 * iqr) #upper bound

print('Lower Bound : ',lwr_bound)
print('Upper Bound: ',upr_bound)
# Out:
# Quartil 1 (Q1) untuk Movie: 75.0
# Quartil 3 (Q3) untuk Movie: 106.0
# IQR :  31.0
# Lower Bound :  28.5
# Upper Bound:  152.5

# %% [markdown]
# Arrange the rows of the DataFrame in descending order based on the values in the 'duration_num' column.
#
# In the context of movies, this operation would arrange the movies from the longest to the shortest duration.

# %%
movie_df.sort_values(by='duration_num', ascending=False)
# Out:
#      show_id   type                                              title  \
# 933     s934  Movie  Soothing Surf at Del Norte for Sleep black screen
# 3850   s3851  Movie                    Himalayan Singing Bowls 9 hours
# 4087   s4088  Movie                Thunderstorm for sleep black screen
# 5214   s5215  Movie         Black Screen Ocean Waves for Sleep 9 hours
# 1673   s1674  Movie            Midnight Thunderstorm for Sleep 9 Hours
# ...      ...    ...                                                ...
# 5701   s5702  Movie                         PrimeVideoQATestMovie16 US
# 5162   s5163  Movie                      Asin_tombstone_test_target_04
# 1381   s1382  Movie             Paradise Canyon - Digitally Remastered
# 5191   s5192  Movie                           Asintombstonetest-target
# 8575   s8576  Movie                     ProjectUNUnApprovedMovieTarget
#
#               director                                               cast  \
# 933        Mark Knight                                        Unavailable
# 3850       Mark Knight                             Niv Dayan, Sarah Lærke
# 4087       Mark Knight                                        Unavailable
# 5214       Mark Knight                                        Unavailable
# 1673       Mark Knight                                        Unavailable
# ...                ...                                                ...
# 5701  Test Director US                        Test Actor1 US, Test Actor2
# 5162     Test Director                         Test Actor 1, Test Actor 2
# 1381      Carl Pierson  John Wayne, Marion Burns, Earle Hodgins, Yakim...
# 5191     Test Director                         Test Actor 1, Test Actor 2
# 8575     Test Director                         Test Actor 1, Test Actor 2
#
#       release_year rating                     categories  \
# 933           2018    ALL               Special Interest
# 3850          2017    ALL               Special Interest
# 4087          2017    ALL  Documentary, Special Interest
# 5214          2017    ALL               Special Interest
# 1673          2014    ALL               Special Interest
# ...            ...    ...                            ...
# 5701          2015      G                  Action, Drama
# 5162          2019      G                         Comedy
# 1381          1935     7+              Action, Adventure
# 5191          2019      G                         Comedy
# 8575          2019      G                         Comedy
#
#                                             description  duration_num  \
# 933   Black screen reduces the blue-spectrum light w...         601.0
# 3850  This ambient sleep and meditation video is a f...         550.0
# 4087  Black screen for a deep, restful sleep accompa...         541.0
# 5214  This black screen recording of the winter Paci...         541.0
# 1673  Our most popular ambient sleep video is a full...         541.0
# ...                                                 ...           ...
# 5701  PrimeVideoQATestMovie16 US Title Summary Goes ...           0.0
# 5162                asin_tombstone_test_target_04 short           0.0
# 1381  An undercover agent for the government is sent...           0.0
# 5191                     asintombstonetest-target short           0.0
# 8575               projectUNUnApprovedMovieTarget short           0.0
#
#      duration_movie duration_season            Genre1             Genre2  \
# 933             601     Unavailable  Special Interest        Unavailable
# 3850            550     Unavailable  Special Interest        Unavailable
# 4087            541     Unavailable       Documentary   Special Interest
# 5214            541     Unavailable  Special Interest        Unavailable
# 1673            541     Unavailable  Special Interest        Unavailable
# ...             ...             ...               ...                ...
# 5701              0     Unavailable            Action              Drama
# 5162              0     Unavailable            Comedy        Unavailable
# 1381              0     Unavailable            Action          Adventure
# 5191              0     Unavailable            Comedy        Unavailable
# 8575              0     Unavailable            Comedy        Unavailable
#
#            Genre3
# 933   Unavailable
# 3850  Unavailable
# 4087  Unavailable
# 5214  Unavailable
# 1673  Unavailable
# ...           ...
# 5701  Unavailable
# 5162  Unavailable
# 1381  Unavailable
# 5191  Unavailable
# 8575  Unavailable
#
# [7814 rows x 15 columns]

# %% [markdown]
# Filter and select rows from the sorted DataFrame movie_df_sorted where the 'duration_num' values fall outside a specific range.

# %%
movie_df_sorted = movie_df.sort_values(by='duration_num', ascending=False)
movie_df_sorted[(movie_df_sorted['duration_num'] > 152) | (movie_df_sorted['duration_num'] < 28)]
# Out:
#      show_id   type                                              title  \
# 933     s934  Movie  Soothing Surf at Del Norte for Sleep black screen
# 3850   s3851  Movie                    Himalayan Singing Bowls 9 hours
# 4087   s4088  Movie                Thunderstorm for sleep black screen
# 5214   s5215  Movie         Black Screen Ocean Waves for Sleep 9 hours
# 1673   s1674  Movie            Midnight Thunderstorm for Sleep 9 Hours
# ...      ...    ...                                                ...
# 5701   s5702  Movie                         PrimeVideoQATestMovie16 US
# 5162   s5163  Movie                      Asin_tombstone_test_target_04
# 1381   s1382  Movie             Paradise Canyon - Digitally Remastered
# 5191   s5192  Movie                           Asintombstonetest-target
# 8575   s8576  Movie                     ProjectUNUnApprovedMovieTarget
#
#               director                                               cast  \
# 933        Mark Knight                                        Unavailable
# 3850       Mark Knight                             Niv Dayan, Sarah Lærke
# 4087       Mark Knight                                        Unavailable
# 5214       Mark Knight                                        Unavailable
# 1673       Mark Knight                                        Unavailable
# ...                ...                                                ...
# 5701  Test Director US                        Test Actor1 US, Test Actor2
# 5162     Test Director                         Test Actor 1, Test Actor 2
# 1381      Carl Pierson  John Wayne, Marion Burns, Earle Hodgins, Yakim...
# 5191     Test Director                         Test Actor 1, Test Actor 2
# 8575     Test Director                         Test Actor 1, Test Actor 2
#
#       release_year rating                     categories  \
# 933           2018    ALL               Special Interest
# 3850          2017    ALL               Special Interest
# 4087          2017    ALL  Documentary, Special Interest
# 5214          2017    ALL               Special Interest
# 1673          2014    ALL               Special Interest
# ...            ...    ...                            ...
# 5701          2015      G                  Action, Drama
# 5162          2019      G                         Comedy
# 1381          1935     7+              Action, Adventure
# 5191          2019      G                         Comedy
# 8575          2019      G                         Comedy
#
#                                             description  duration_num  \
# 933   Black screen reduces the blue-spectrum light w...         601.0
# 3850  This ambient sleep and meditation video is a f...         550.0
# 4087  Black screen for a deep, restful sleep accompa...         541.0
# 5214  This black screen recording of the winter Paci...         541.0
# 1673  Our most popular ambient sleep video is a full...         541.0
# ...                                                 ...           ...
# 5701  PrimeVideoQATestMovie16 US Title Summary Goes ...           0.0
# 5162                asin_tombstone_test_target_04 short           0.0
# 1381  An undercover agent for the government is sent...           0.0
# 5191                     asintombstonetest-target short           0.0
# 8575               projectUNUnApprovedMovieTarget short           0.0
#
#      duration_movie duration_season            Genre1             Genre2  \
# 933             601     Unavailable  Special Interest        Unavailable
# 3850            550     Unavailable  Special Interest        Unavailable
# 4087            541     Unavailable       Documentary   Special Interest
# 5214            541     Unavailable  Special Interest        Unavailable
# 1673            541     Unavailable  Special Interest        Unavailable
# ...             ...             ...               ...                ...
# 5701              0     Unavailable            Action              Drama
# 5162              0     Unavailable            Comedy        Unavailable
# 1381              0     Unavailable            Action          Adventure
# 5191              0     Unavailable            Comedy        Unavailable
# 8575              0     Unavailable            Comedy        Unavailable
#
#            Genre3
# 933   Unavailable
# 3850  Unavailable
# 4087  Unavailable
# 5214  Unavailable
# 1673  Unavailable
# ...           ...
# 5701  Unavailable
# 5162  Unavailable
# 1381  Unavailable
# 5191  Unavailable
# 8575  Unavailable
#
# [601 rows x 15 columns]

# %% [markdown]
# ### Save Clean Data in CSV format

# %%
df_clean = pd.DataFrame(df)
df_clean.to_csv("amazon_clean.csv")
df_clean
# Out:
#      show_id     type                    title         director  \
# 0         s1    Movie      The Grand Seduction     Don McKellar
# 1         s2    Movie     Take Care Good Night     Girish Joshi
# 2         s3    Movie     Secrets of Deception      Josh Webber
# 3         s4    Movie       Pink: Staying True   Sonia Anderson
# 4         s5    Movie            Monster Maker     Giles Foster
# ...      ...      ...                      ...              ...
# 9663   s9664    Movie      Pride Of The Bowery  Joseph H. Lewis
# 9664   s9665  TV Show            Planet Patrol      Unavailable
# 9665   s9666    Movie                  Outpost     Steve Barker
# 9666   s9667  TV Show  Maradona: Blessed Dream      Unavailable
# 9667   s9668    Movie              Harry Brown    Daniel Barber
#
#                                                    cast  release_year rating  \
# 0        Brendan Gleeson, Taylor Kitsch, Gordon Pinsent          2014    13+
# 1      Mahesh Manjrekar, Abhay Mahajan, Sachin Khedekar          2018    13+
# 2     Tom Sizemore, Lorenzo Lamas, Robert LaSardo, R...          2017    13+
# 3     Interviews with: Pink, Adele, Beyoncé, Britney...          2014    13+
# 4     Harry Dean Stanton, Kieran O'Brien, George Cos...          1989    13+
# ...                                                 ...           ...    ...
# 9663                           Leo Gorcey, Bobby Jordan          1940     7+
# 9664  DICK VOSBURGH, RONNIE STEVENS, LIBBY MORRIS, M...          2018    13+
# 9665  Ray Stevenson, Julian Wadham, Richard Brake, M...          2008      R
# 9666  Esteban Recagno, Ezequiel Stremiz, Luciano Vit...          2021  TV-MA
# 9667  Michael Caine, Emily Mortimer, Joseph Gilgun, ...          2010      R
#
#                    categories  \
# 0               Comedy, Drama
# 1        Drama, International
# 2     Action, Drama, Suspense
# 3                 Documentary
# 4              Drama, Fantasy
# ...                       ...
# 9663                   Comedy
# 9664                 TV Shows
# 9665                   Action
# 9666            Drama, Sports
# 9667  Action, Drama, Suspense
#
#                                             description  duration_num  \
# 0     A small fishing village must procure a local d...         113.0
# 1     A Metro Family decides to fight a Cyber Crimin...         110.0
# 2     After a man discovers his wife is cheating on ...          74.0
# 3     Pink breaks the mold once again, bringing her ...          69.0
# 4     Teenage Matt Banting wants to work with a famo...          45.0
# ...                                                 ...           ...
# 9663  New York City street principles get an East Si...          60.0
# 9664  This is Earth, 2100AD - and these are the adve...           4.0
# 9665  In war-torn Eastern Europe, a world-weary grou...          90.0
# 9666  The series tells the story of Diego Maradona, ...           1.0
# 9667  Harry Brown, starring two-time Academy Award w...         103.0
#
#      duration_movie duration_season       Genre1          Genre2       Genre3
# 0               113     Unavailable       Comedy           Drama  Unavailable
# 1               110     Unavailable        Drama   International  Unavailable
# 2                74     Unavailable       Action           Drama     Suspense
# 3                69     Unavailable  Documentary     Unavailable  Unavailable
# 4                45     Unavailable        Drama         Fantasy  Unavailable
# ...             ...             ...          ...             ...          ...
# 9663             60     Unavailable       Comedy     Unavailable  Unavailable
# 9664    Unavailable               4     TV Shows     Unavailable  Unavailable
# 9665             90     Unavailable       Action     Unavailable  Unavailable
# 9666    Unavailable     Unavailable        Drama          Sports  Unavailable
# 9667            103     Unavailable       Action           Drama     Suspense
#
# [9668 rows x 15 columns]
